# %%
import pandas as pd
import numpy as np

np.random.seed(12345)

df = pd.DataFrame([np.random.normal(32000,200000,3650), 
                   np.random.normal(43000,100000,3650), 
                   np.random.normal(43500,140000,3650), 
                   np.random.normal(48000,70000,3650)], 
                  index=[1992,1993,1994,1995])
mean = df.mean(axis=1).tolist()
std = df.std(axis=1)
n=df.shape[1]

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib notebook

# %%
df=df.T
df.head()
# Out:
#             1992           1993           1994           1995
# 0   -8941.531897  -51896.094813  152336.932066  -69708.439062
# 1  127788.667612  198350.518755  192947.128056  -13289.977022
# 2  -71887.743011 -123518.252821  389950.263156  -30178.390991
# 3  -79146.060869 -129916.759685  -93006.152024   55052.181256
# 4  425156.114501  216119.147314  100818.575896  152883.621657

# %%
n=df.shape[0]
std=df.std(axis=0).values.tolist()
se=std/np.sqrt(n)
y=df.mean(axis=0)
colm=plt.cm.get_cmap('Blues')
yabs=39500
diff=y-min(y)
cols=diff/max(diff)

# %%
plt.ylim(30000,50000)
plt.bar(range(len(df.columns)),y,tick_label=list(df.columns),color=colm(cols),yerr=se,capsize=15)
plt.axhline(y=yabs,color='grey')
sm=cm.ScalarMappable(norm=plt.Normalize(0,max(cols)),cmap=colm)
sm.set_array([])
cbar=plt.colorbar(sm,ticks=np.arange(0,1.2,0.2))
cbar.ax.set_yticklabels(np.linspace(30000,50000,6))
# Out:
# <img src="data:image/png;base64,..." width="852.75">
# [Text(1, 0, '30000.0'),
#  Text(1, 0, '34000.0'),
#  Text(1, 0, '38000.0'),
#  Text(1, 0, '42000.0'),
#  Text(1, 0, '46000.0'),
#  Text(1, 0, '50000.0')]
